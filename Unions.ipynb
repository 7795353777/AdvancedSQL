# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
s=["a"]
d=[(1,),(2,),(2,),(2,),(3,),(4,),(None,),(None,)]
Ldf=spark.createDataFrame(d,s)
display(Ldf)
rs=["a"]
rd=[(1,),(1,),(2,),(3,),(5,),(None,)]
Rdf=spark.createDataFrame(rd,rs)
display(Rdf)
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 02d0d5ae-17f5-4951-bf4f-c2c6a83990d0)
# SynapseWidget(Synapse.DataFrame, 60240ab0-52c5-48ce-8889-53317ace1219)

# %%
Rdf.createOrReplaceTempView("bb")
Ldf.createOrReplaceTempView("aa")
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 7, Finished, Available, Finished)

# %%
# %%sql
# select * from aa UNION SELECT * from bb
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 9, Finished, Available, Finished)
# <Spark SQL result set with 6 rows and 1 fields>

# %%
# %%sql
# select * from aa INTERSECT SELECT * from bb
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 10, Finished, Available, Finished)
# <Spark SQL result set with 4 rows and 1 fields>

# %%
# %%sql
# select * from aa UNION ALL SELECT * from bb order by 1
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 12, Finished, Available, Finished)
# <Spark SQL result set with 14 rows and 1 fields>

# %%
s=["a", "b"]
d=[(1,"a"),(2,"a"),(2,"b"),(2,"c")]
Ldf=spark.createDataFrame(d,s)
display(Ldf)
rs=["a", "b"]
rd=[(1,"a"),(1,"b"),(2,"a"),(2,"a")]
Rdf=spark.createDataFrame(rd,rs)
display(Rdf)

Rdf.createOrReplaceTempView("bb")
Ldf.createOrReplaceTempView("aa")

display(spark.sql("""
select * from aa UNION SELECT * from bb
"""))
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 15, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 120b0b69-bb3d-46ce-b4ff-93caabde9be5)
# SynapseWidget(Synapse.DataFrame, e114f47e-7d12-4a4c-bbd2-7890ecf06358)
# SynapseWidget(Synapse.DataFrame, 597b0c47-f1c0-45fd-9ef3-cfc452333c75)

# %%
# %%sql
# SELECT * from aa union all select * from bb order by 1,2
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 19, Finished, Available, Finished)
# <Spark SQL result set with 8 rows and 2 fields>

# %%
# %%sql
# SELECT * from aa union  select * from bb order by 1,2
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 20, Finished, Available, Finished)
# <Spark SQL result set with 5 rows and 2 fields>

# %%
# %%sql
# SELECT * from aa INTERSECT all select * from bb order by 1,2
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 23, Finished, Available, Finished)
# <Spark SQL result set with 2 rows and 2 fields>

# %%
s=["a", "b","c"]
d=[(1,"a",0),(2,"a",None),(2,"b",None),(2,"c",None)]
Ldf=spark.createDataFrame(d,s)
display(Ldf)
rs=["a", "c",'b']
rd=[(1,"a",'a'),(1,"b",'a'),(2,"a",'a'),(2,"a",'a')]
Rdf=spark.createDataFrame(rd,rs)
display(Rdf)

Rdf.createOrReplaceTempView("bb")
Ldf.createOrReplaceTempView("aa")

display(spark.sql("""
select * from bb UNION all SELECT * from aa
"""))
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 37, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 7a54bc80-683c-47c5-8083-6e7871de5750)
# SynapseWidget(Synapse.DataFrame, 980aa5bb-b7c8-49da-860d-42ddbd11b5bc)
# SynapseWidget(Synapse.DataFrame, 884904fc-3569-433e-b429-013af6f5d316)

# %%
# %%sql
# SELECT * from aa union  select * from bb
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 33, Finished, Available, Finished)
# [NUM_COLUMNS_MISMATCH] UNION can only be performed on inputs with the same number of columns, but the first input has 3 columns and the second input has 2 columns.; line 1 pos 0;
# 'Distinct
# +- 'Union false, false
#    :- Project [a#1036L, b#1037, c#1038L]
#    :  +- SubqueryAlias aa
#    :     +- View (`aa`, [a#1036L,b#1037,c#1038L])
#    :        +- LogicalRDD [a#1036L, b#1037, c#1038L], false
#    +- Project [a#1058L, c#1059]
#       +- SubqueryAlias bb
#          +- View (`bb`, [a#1058L,c#1059])
#             +- LogicalRDD [a#1058L, c#1059], false
#
# org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.failAnalysis(package.scala:52)
# org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$37(CheckAnalysis.scala:612)
# org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$37$adapted(CheckAnalysis.scala:603)
# ...

# %%
display(Ldf.unionAll(Rdf))
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 35, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 30b57323-f125-4dc8-a8bc-f41cc6e7e9d3)

# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
s=["a"]
d=[(1,),(2,),(2,),(2,),(3,),(4,),(None,),(None,)]
Ldf=spark.createDataFrame(d,s)
display(Ldf)
rs=["a"]
rd=[(1,),(1,),(2,),(3,),(5,),(None,)]
Rdf=spark.createDataFrame(rd,rs)


Rdf.createOrReplaceTempView("bb")
Ldf.createOrReplaceTempView("aa")

display(Rdf)
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 40, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, de1b3b06-35db-4c79-89d7-339ed237dbd1)
# SynapseWidget(Synapse.DataFrame, 40e9fb4b-3ec2-48eb-a9b5-352c7af99436)

# %%
# %%sql
#
# select * from aa EXCEPT   SELECT * from bb
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 50, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
s=["a", "b"]
d=[(1,"a"),(2,"a"),(2,"b"),(2,"c"),(3,None),(4,'a')]
Ldf=spark.createDataFrame(d,s)
display(Ldf)
rs=["a", "b"]
rd=[(1,"a"),(1,"b"),(2,"a"),(2,"a"),(None,None),(4,'b')]
Rdf=spark.createDataFrame(rd,rs)
display(Rdf)

Rdf.createOrReplaceTempView("bb")
Ldf.createOrReplaceTempView("aa")
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 52, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, eb51392a-87fe-4632-9b5a-3fc0f1736f7f)
# SynapseWidget(Synapse.DataFrame, 98428e90-b5d7-4d34-b7c8-56e646302413)

# %%
# %%sql
# select * from aa except  SELECT * from bb order by 1,2
# Out:
# StatementMeta(, 528fa238-6260-4cf1-b6a8-5756635e4efe, 61, Finished, Available, Finished)
# <Spark SQL result set with 4 rows and 2 fields>

# %%
s=["a", "b","c"]
d=[(1,"a",0),(2,"a",None),(2,"b",None),(2,"c",None),(None,None,None)]
Ldf=spark.createDataFrame(d,s)
display(Ldf)
rs=["a", "c",'b']
rd=[("x",1,'a'),("y",2,'a'),("z","3",'a'),(None,None,'a'),(None,None,None)]
Rdf=spark.createDataFrame(rd,rs)
display(Rdf)

Rdf.createOrReplaceTempView("bb")
Ldf.createOrReplaceTempView("aa")
# Out:
# StatementMeta(, 21ed8341-d7e4-4ae7-9be9-258b2f84bcff, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, bf003db7-6751-47ef-8a9e-99cd7a9bbce7)
# SynapseWidget(Synapse.DataFrame, a5120d90-dcdc-4e7a-89fd-5f4700536202)

# %%
# %%sql
# select * from aa union  SELECT * from bb order by 1,2
# Out:
# StatementMeta(, 21ed8341-d7e4-4ae7-9be9-258b2f84bcff, 5, Finished, Available, Finished)
# <Spark SQL result set with 9 rows and 3 fields>
